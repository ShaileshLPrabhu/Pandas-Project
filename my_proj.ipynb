# %% [markdown]
# <u>Importing data from csv</u>

# %%
import pandas as pd
df= pd.read_csv('customer.csv')

# %% [markdown]
# <u>Which products are cheapest(to purchase in bulk)?</u>

# %%
d=df['UnitPrice']<10
df[d]
# Out:
#                 InvoiceDate InvoiceNo StockCode  \
# 0       2010-12-01 08:26:00    536365    85123A
# 1       2010-12-01 08:26:00    536365     71053
# 2       2010-12-01 08:26:00    536365    84406B
# 3       2010-12-01 08:26:00    536365    84029G
# 4       2010-12-01 08:26:00    536365    84029E
# ...                     ...       ...       ...
# 541904  2011-12-09 12:50:00    581587     22613
# 541905  2011-12-09 12:50:00    581587     22899
# 541906  2011-12-09 12:50:00    581587     23254
# 541907  2011-12-09 12:50:00    581587     23255
# 541908  2011-12-09 12:50:00    581587     22138
#
#                                 Description  Quantity  UnitPrice  CustomerID  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55     17850.0
# 1                       WHITE METAL LANTERN         6       3.39     17850.0
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75     17850.0
# ...

# %% [markdown]
# Conclusion: Products like WHITE HANGING HEART T-LIGHT HOLDER and CHILDRENS CUTLERY have low unit price hence making them less costly to buy in bulk

# %% [markdown]
# <u>Which products are mostly ordered in high quantity?</u>

# %%
d2=df['Quantity']>1000
df[d2]
# Out:
#                 InvoiceDate InvoiceNo StockCode  \
# 4850    2010-12-02 16:48:00    536809     84950
# 4945    2010-12-02 17:38:00    536830     84077
# 4946    2010-12-02 17:38:00    536830     21915
# 6365    2010-12-03 11:48:00    536890    17084R
# 16435   2010-12-07 16:43:00    537659     22189
# ...                     ...       ...       ...
# 533812  2011-12-07 12:20:00    581115     22413
# 534952  2011-12-07 15:16:00    581175     23084
# 540070  2011-12-08 18:45:00    581458     22197
# 540071  2011-12-08 18:46:00    581459     22197
# 540421  2011-12-09 09:15:00    581483     23843
#
#                               Description  Quantity  UnitPrice  CustomerID  \
# 4850       ASSORTED COLOUR T-LIGHT HOLDER      1824       0.55     15299.0
# 4945    WORLD WAR 2 GLIDERS ASSTD DESIGNS      2880       0.18     16754.0
# 4946               RED  HARMONICA IN BOX       1400       1.06     16754.0
# 6365                ASSORTED INCENSE PACK      1440       0.16     14156.0
# ...

# %% [markdown]
# Conclusion: POPCORN HOLDER , T-LIGHT HOLDER etc are bought in high quanity

# %% [markdown]
# <u>Most ordered product in uk?</u>

# %%
d=df['Country']=='United Kingdom'
x=df[d]
x.groupby('Description')['StockCode'].size().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER     2271
# JUMBO BAG RED RETROSPOT                2001
# REGENCY CAKESTAND 3 TIER               1859
# PARTY BUNTING                          1634
# LUNCH BAG RED RETROSPOT                1460
#                                        ...
# S/4 BLACK DISCO PARTITION PANEL           1
# FOUND                                     1
# WIRE FLOWER T-LIGHT HOLDER                1
# FOOD COVER WITH BEADS , SET 2 SIZES       1
# wrongly sold sets                         1
# Name: StockCode, Length: 4202, dtype: int64

# %% [markdown]
# Conclusion:WHITE HANGING HEART T-LIGHT HOLDER are most sold in the uk

# %% [markdown]
# <u>Which country do we get most orders from?</u>

# %%
custbycountry=df.groupby('Country')['StockCode'].nunique().sort_values(ascending= False)
custbycountry
# Out:
# Country
# United Kingdom          4065
# EIRE                    1976
# Germany                 1671
# France                  1543
# Spain                   1093
# Switzerland              978
# Netherlands              785
# Belgium                  778
# Portugal                 706
# Australia                600
# Norway                   591
# Cyprus                   498
# Italy                    477
# Finland                  458
# Channel Islands          430
# Unspecified              344
# Austria                  307
# Sweden                   261
# Israel                   256
# Denmark                  251
# Japan                    216
# Poland                   204
# Hong Kong                191
# Singapore                178
# USA                      163
# Canada                   147
# Greece                   138
# Iceland                  103
# Malta                     99
# United Arab Emirates      68
# RSA                       58
# ...

# %% [markdown]
# Conclusion:Most Orders are from United Kingdom

# %% [markdown]
# <u>Which product is most sold?</u>

# %%
product_sales=df.groupby('Description')['Quantity']
product_sales.size().sort_values(ascending=False)
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
#                                       ...
# FRYING PAN RED POLKADOT                  1
# S/4 BLACK DISCO PARTITION PANEL          1
# SCALLOP SHELL SOAP DISH                  1
# FOUND                                    1
# wrongly sold sets                        1
# Name: Quantity, Length: 4223, dtype: int64

# %% [markdown]
# "WHITE HANGING HEART T-LIGHT HOLDER" are the most sold sold upto 1930 units

# %% [markdown]
# <u>Which country orders most of the products?</u>

# %%
country_sales=df.groupby('Country')['StockCode'].nunique().sort_values(ascending= False)
country_sales
# Out:
# Country
# United Kingdom          4065
# EIRE                    1976
# Germany                 1671
# France                  1543
# Spain                   1093
# Switzerland              978
# Netherlands              785
# Belgium                  778
# Portugal                 706
# Australia                600
# Norway                   591
# Cyprus                   498
# Italy                    477
# Finland                  458
# Channel Islands          430
# Unspecified              344
# Austria                  307
# Sweden                   261
# Israel                   256
# Denmark                  251
# Japan                    216
# Poland                   204
# Hong Kong                191
# Singapore                178
# USA                      163
# Canada                   147
# Greece                   138
# Iceland                  103
# Malta                     99
# United Arab Emirates      68
# RSA                       58
# ...

# %% [markdown]
# Conclusion: Most of the products are getting orders from United Kingdom

# %% [markdown]
# <u>Does income and the quantity of products ordered have a relation?</u>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
d= pd.read_csv('customer.csv')
salary= d['Income'].drop_duplicates()
data = {'Income': salary.head(),
        'Quantity': d['Quantity']
       }
df = pd.DataFrame(data,columns=['Income','Quantity'])
# df.plot(x ='Income', y='Quantity', kind = 'line')
sns.barplot(x=df['Income'],y=df['Quantity'],data=df)
plt.xticks(rotation=30,ha='right')
plt.show()

# %% [markdown]
# Conclusion: In some cases more the income more the quantity but some customers with high income ordered less than they could

# %% [markdown]
# <u>Does unit price and quantity have a relation?</u>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
d= pd.read_csv('customer.csv')
data = {'UnitPrice': d['UnitPrice'].tail(10),
        'Quantity':  d['Quantity']
       }
df = pd.DataFrame(data,columns=['UnitPrice','Quantity'])
df.apply(pd.to_numeric)
sns.barplot(x=df['UnitPrice'],y=df['Quantity'])
plt.show()

# %% [markdown]
# Conclusion:Products with low unit price are ordered in high quantity confirming the assumption.

# %% [markdown]
# <u>Which gender is the most purchasing?</u>

# %%
custbygender=df.groupby('Gender')['StockCode'].nunique().sort_values(ascending= False)
custbygender
# Out:
# Gender
# female    4049
# male      3447
# Name: StockCode, dtype: int64

# %% [markdown]
# Conclusion: Woman order more than men

# %% [markdown]
# <u>How did we perform during the financial year?</u>

# %%
df2 = df.query("InvoiceDate >= '2010-04-01' and InvoiceDate	 < '2011-04-01'")
df2
# Out:
#                 InvoiceDate InvoiceNo StockCode  \
# 0       2010-12-01 08:26:00    536365    85123A
# 1       2010-12-01 08:26:00    536365     71053
# 2       2010-12-01 08:26:00    536365    84406B
# 3       2010-12-01 08:26:00    536365    84029G
# 4       2010-12-01 08:26:00    536365    84029E
# ...                     ...       ...       ...
# 142078  2011-03-31 19:54:00    548548     22423
# 142079  2011-03-31 19:54:00    548548     21361
# 142080  2011-03-31 19:55:00    548549     84763
# 142081  2011-03-31 19:55:00    548549     22222
# 142082  2011-03-31 19:55:00    548549     22776
#
#                                 Description  Quantity  UnitPrice  CustomerID  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55     17850.0
# 1                       WHITE METAL LANTERN         6       3.39     17850.0
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75     17850.0
# ...

# %% [markdown]
# Conclusion: We have performed good during the fiinancial year

# %% [markdown]
# <u>What is the Performance of the year 2011?</u>

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'], format='%Y-%m-%d')
df2 = df[df["InvoiceDate"].dt.strftime('%Y') == "2011"]
df2
# Out:
#                InvoiceDate InvoiceNo StockCode  \
# 42481  2011-01-04 10:00:00    539993     22386
# 42482  2011-01-04 10:00:00    539993     21499
# 42483  2011-01-04 10:00:00    539993     21498
# 42484  2011-01-04 10:00:00    539993     22379
# 42485  2011-01-04 10:00:00    539993     20718
# ...                    ...       ...       ...
# 541904 2011-12-09 12:50:00    581587     22613
# 541905 2011-12-09 12:50:00    581587     22899
# 541906 2011-12-09 12:50:00    581587     23254
# 541907 2011-12-09 12:50:00    581587     23255
# 541908 2011-12-09 12:50:00    581587     22138
#
#                             Description  Quantity  UnitPrice  CustomerID  Age  \
# 42481           JUMBO BAG PINK POLKADOT        10       1.95     13313.0   17
# 42482                BLUE POLKADOT WRAP        25       0.42     13313.0   17
# 42483               RED RETROSPOT WRAP         25       0.42     13313.0   17
# 42484          RECYCLING BAG RETROSPOT          5       2.10     13313.0   17
# ...

# %% [markdown]
# Conclusion: During the beginning of the year sales were getting better in the United Kingdom but during the end of the year sales decreased gradually in France

# %% [markdown]
# <u>Quaterly Sales?</u>

# %%
df2 = df.query("InvoiceDate >= '2011-01-01' and InvoiceDate < '2011-04-01'")
df2
# Out:
#                 InvoiceDate InvoiceNo StockCode  \
# 42481   2011-01-04 10:00:00    539993     22386
# 42482   2011-01-04 10:00:00    539993     21499
# 42483   2011-01-04 10:00:00    539993     21498
# 42484   2011-01-04 10:00:00    539993     22379
# 42485   2011-01-04 10:00:00    539993     20718
# ...                     ...       ...       ...
# 142078  2011-03-31 19:54:00    548548     22423
# 142079  2011-03-31 19:54:00    548548     21361
# 142080  2011-03-31 19:55:00    548549     84763
# 142081  2011-03-31 19:55:00    548549     22222
# 142082  2011-03-31 19:55:00    548549     22776
#
#                           Description  Quantity  UnitPrice  CustomerID  Age  \
# 42481         JUMBO BAG PINK POLKADOT        10       1.95     13313.0   17
# 42482              BLUE POLKADOT WRAP        25       0.42     13313.0   17
# 42483             RED RETROSPOT WRAP         25       0.42     13313.0   17
# 42484        RECYCLING BAG RETROSPOT          5       2.10     13313.0   17
# ...

# %% [markdown]
# Conclusion: during the quarter the business is doing well products have been sold to upto 100 units in quantity
